# %%
import pandas as pd
import pickle

# %%
data = pd.read_csv(
  '/home/zunaira/Downloads/SimulatedDATA/simulatedHulk traffic.csv')

# %%
data.shape
# Out:
# (25541, 84)

# %%
data.sample(10)
# Out:
#                                  Flow ID     Src IP  Src Port        Dst IP  \
# 4668   192.168.10.5-10.0.2.15-80-43722-6  10.0.2.15     43722  192.168.10.5
# 9425   192.168.10.5-10.0.2.15-80-50328-6  10.0.2.15     50328  192.168.10.5
# 16286  192.168.10.5-10.0.2.15-80-57344-6  10.0.2.15     57344  192.168.10.5
# 3659   192.168.10.5-10.0.2.15-80-39194-6  10.0.2.15     39194  192.168.10.5
# 25104  192.168.10.5-10.0.2.15-80-59622-6  10.0.2.15     59622  192.168.10.5
# 5645   192.168.10.5-10.0.2.15-80-58284-6  10.0.2.15     58284  192.168.10.5
# 19553  192.168.10.5-10.0.2.15-80-44814-6  10.0.2.15     44814  192.168.10.5
# 4834   192.168.10.5-10.0.2.15-80-46568-6  10.0.2.15     46568  192.168.10.5
# 2895   192.168.10.5-10.0.2.15-80-35158-6  10.0.2.15     35158  192.168.10.5
# 6926   192.168.10.5-10.0.2.15-80-32968-6  10.0.2.15     32968  192.168.10.5
#
#        Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# ...

# %%
data.columns = data.columns.str.lower().str.strip().str.replace(
    ' ', '_').str.replace('/s', '').str.replace('/', '_').str.replace('.', '_')

# %%
data.sample(10)
# Out:
#                                  flow_id     src_ip  src_port        dst_ip  \
# 24657  192.168.10.5-10.0.2.15-80-56864-6  10.0.2.15     56864  192.168.10.5
# 4191   192.168.10.5-10.0.2.15-80-42768-6  10.0.2.15     42768  192.168.10.5
# 14244  192.168.10.5-10.0.2.15-80-39020-6  10.0.2.15     39020  192.168.10.5
# 4952   192.168.10.5-10.0.2.15-80-46804-6  10.0.2.15     46804  192.168.10.5
# 17245  192.168.10.5-10.0.2.15-80-46688-6  10.0.2.15     46688  192.168.10.5
# 6434   192.168.10.5-10.0.2.15-80-45626-6  10.0.2.15     45626  192.168.10.5
# 16112  192.168.10.5-10.0.2.15-80-48512-6  10.0.2.15     48512  192.168.10.5
# 4302   192.168.10.5-10.0.2.15-80-42990-6  10.0.2.15     42990  192.168.10.5
# 6612   192.168.10.5-10.0.2.15-80-60572-6  10.0.2.15     60572  192.168.10.5
# 23630  192.168.10.5-10.0.2.15-80-52200-6  10.0.2.15     52200  192.168.10.5
#
#        dst_port  protocol            timestamp  flow_duration  tot_fwd_pkts  \
# ...

# %%
#writing clean HULK Data
data.to_csv('/home/zunaira/Downloads/CLEAN_DATA/CICFlowData_clean_HULK.csv', index=False)

# %%
tstdt= pd.read_csv('/home/zunaira/Downloads/CLEAN_DATA/CICFlowData_clean_HULK.csv')

# %%
tstdt.sample(50)
# Out:
#                                  flow_id     src_ip  src_port        dst_ip  \
# 9484   192.168.10.5-10.0.2.15-80-50446-6  10.0.2.15     50446  192.168.10.5
# 9889   192.168.10.5-10.0.2.15-80-51256-6  10.0.2.15     51256  192.168.10.5
# 10952  192.168.10.5-10.0.2.15-80-53334-6  10.0.2.15     53334  192.168.10.5
# 18962  192.168.10.5-10.0.2.15-80-40612-6  10.0.2.15     40612  192.168.10.5
# 13407  192.168.10.5-10.0.2.15-80-34544-6  10.0.2.15     34544  192.168.10.5
# 3329   192.168.10.5-10.0.2.15-80-38534-6  10.0.2.15     38534  192.168.10.5
# 16638  192.168.10.5-10.0.2.15-80-58048-6  10.0.2.15     58048  192.168.10.5
# 15587  192.168.10.5-10.0.2.15-80-47346-6  10.0.2.15     47346  192.168.10.5
# 15680  192.168.10.5-10.0.2.15-80-47532-6  10.0.2.15     47532  192.168.10.5
# 14373  192.168.10.5-10.0.2.15-80-39278-6  10.0.2.15     39278  192.168.10.5
# 18043  192.168.10.5-10.0.2.15-80-42500-6  10.0.2.15     42500  192.168.10.5
# ...
