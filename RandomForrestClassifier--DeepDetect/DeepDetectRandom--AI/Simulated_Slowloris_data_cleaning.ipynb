# %%
import pandas as pd
import pickle

# %%
data = pd.read_csv(
  '/home/zunaira/Downloads/SimulatedDATA/SimulatedSlowlorisTraffic.csv')
data.shape
# Out:
# (25279, 84)

# %%
data.sample(50)
# Out:
#                                    Flow ID     Src IP  Src Port  \
# 12484    192.168.10.5-10.0.2.15-80-54420-6  10.0.2.15     54420
# 18700    192.168.10.5-10.0.2.15-80-38728-6  10.0.2.15     38728
# 19406    192.168.10.5-10.0.2.15-80-40126-6  10.0.2.15     40126
# 9469     192.168.10.5-10.0.2.15-80-48176-6  10.0.2.15     48176
# 2445     192.168.10.5-10.0.2.15-80-33846-6  10.0.2.15     33846
# 147       10.0.2.15-31.13.75.8-58248-443-6  10.0.2.15     58248
# 15098    192.168.10.5-10.0.2.15-80-59734-6  10.0.2.15     59734
# 11665    192.168.10.5-10.0.2.15-80-52742-6  10.0.2.15     52742
# 17612    192.168.10.5-10.0.2.15-80-36552-6  10.0.2.15     36552
# 20340    192.168.10.5-10.0.2.15-80-42000-6  10.0.2.15     42000
# 4759     192.168.10.5-10.0.2.15-80-38560-6  10.0.2.15     38560
# 22198    192.168.10.5-10.0.2.15-80-45732-6  10.0.2.15     45732
# 20190    192.168.10.5-10.0.2.15-80-41714-6  10.0.2.15     41714
# 6615     192.168.10.5-10.0.2.15-80-42378-6  10.0.2.15     42378
# ...

# %%
data.columns = data.columns.str.lower().str.strip().str.replace(
    ' ', '_').str.replace('/s', '').str.replace('/', '_').str.replace('.', '_')

# %%
data.sample(10)
# Out:
#                                  flow_id     src_ip  src_port        dst_ip  \
# 3756   192.168.10.5-10.0.2.15-80-36490-6  10.0.2.15     36490  192.168.10.5
# 18873  192.168.10.5-10.0.2.15-80-39078-6  10.0.2.15     39078  192.168.10.5
# 8524   192.168.10.5-10.0.2.15-80-46248-6  10.0.2.15     46248  192.168.10.5
# 11429  192.168.10.5-10.0.2.15-80-52244-6  10.0.2.15     52244  192.168.10.5
# 4794   192.168.10.5-10.0.2.15-80-38632-6  10.0.2.15     38632  192.168.10.5
# 2493   192.168.10.5-10.0.2.15-80-33944-6  10.0.2.15     33944  192.168.10.5
# 3610   192.168.10.5-10.0.2.15-80-36198-6  10.0.2.15     36198  192.168.10.5
# 17745  192.168.10.5-10.0.2.15-80-36818-6  10.0.2.15     36818  192.168.10.5
# 10615  192.168.10.5-10.0.2.15-80-50558-6  10.0.2.15     50558  192.168.10.5
# 19925  192.168.10.5-10.0.2.15-80-41182-6  10.0.2.15     41182  192.168.10.5
#
#        dst_port  protocol            timestamp  flow_duration  tot_fwd_pkts  \
# ...

# %%
#writing clean HULK Data
data.to_csv('/home/zunaira/Downloads/CLEAN_DATA/CICFlowData_clean_SLOWLORIS.csv', index=False)

# %%
data.shape
# Out:
# (25279, 84)

# %%
tstdt= pd.read_csv(
  '/home/zunaira/Downloads/CLEAN_DATA/CICFlowData_clean_SLOWLORIS.csv')

# %%
tstdt.sample(50)
# Out:
#                                  flow_id     src_ip  src_port        dst_ip  \
# 17433  192.168.10.5-10.0.2.15-80-36182-6  10.0.2.15     36182  192.168.10.5
# 15573  192.168.10.5-10.0.2.15-80-60686-6  10.0.2.15     60686  192.168.10.5
# 24634  192.168.10.5-10.0.2.15-80-50582-6  10.0.2.15     50582  192.168.10.5
# 18747  192.168.10.5-10.0.2.15-80-38822-6  10.0.2.15     38822  192.168.10.5
# 1070   192.168.10.5-10.0.2.15-80-59318-6  10.0.2.15     59318  192.168.10.5
# 7226   192.168.10.5-10.0.2.15-80-43642-6  10.0.2.15     43642  192.168.10.5
# 21586  192.168.10.5-10.0.2.15-80-44502-6  10.0.2.15     44502  192.168.10.5
# 16412  192.168.10.5-10.0.2.15-80-34136-6  10.0.2.15     34136  192.168.10.5
# 3311   192.168.10.5-10.0.2.15-80-35596-6  10.0.2.15     35596  192.168.10.5
# 22522  192.168.10.5-10.0.2.15-80-46372-6  10.0.2.15     46372  192.168.10.5
# 21592  192.168.10.5-10.0.2.15-80-44514-6  10.0.2.15     44514  192.168.10.5
# ...
